# %%
# !pip install -U googlemaps
# Out:
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.6.0-py3-none-any.whl size=38531 sha256=cd4540f9a721d76e36a2f8ab14175d1c25fbd459f1384217726eb5a455de6030
#   Stored in directory: /Users/nimeshroy/Library/Caches/pip/wheels/2d/e9/ee/336c1792ed04efbf4fe9c89662d701f5c1f1fdddf8782951d3
# Successfully built googlemaps
# ...

# %% [markdown]
# # -------------------------------------

# %%
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from time import sleep
from bs4 import BeautifulSoup
import requests
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # Q(1)

# %%
driver=webdriver.Chrome(r'/Users/nimeshroy/Downloads/chromedriver')
driver.get('https://www.amazon.in')
search=input("Type Your Search Here :  ")
driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input').send_keys(search)
driver.find_element_by_xpath('/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]').click()
# Out:
# Type Your Search Here :  smart watches

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # Q(2)

# %%
watch=[]
for i in range(3):
    print("Scraping page no. - ",  i+1)
    bk=driver.find_elements(By.XPATH,'//span[contains(@class,"a-size-medium a-color-base a-text-normal")]')
    for a in bk:
        b=a.text.replace('','')
        watch.append(b.replace('',''))
    click_next=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    click_next.click()
    sleep(3)
len(watch)

# %%
price=[]
for i in range(3):
    print("Scraping page no. - ",  i+1)
    pr=driver.find_elements(By.XPATH,'//span[contains(@class,"a-price-whole")]')
    for p in pr:
        c=p.text.replace('₹',',')
        price.append(c.replace('\n','').split())
    click_next=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    click_next.click()
    sleep(5)
len(price)

# %%
delivery=[]
for i in range(3):
    print("Scraping page no. - ",  i+1)
    dr=driver.find_elements(By.XPATH,'//div[contains(@class,"a-row s-align-children-center")]')
    for d in dr:
        e=d.text.replace('','')
        delivery.append(e.replace('',''))
    click_next=driver.find_element_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
    click_next.click()
    sleep(4)
len(delivery)

# %%
wurl=[]
link=driver.find_elements(By.XPATH,'//a[contains(@class,"a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal")]')
for i in link:
    print(i.get_attribute('href'))
    wurl.append(i.get_attribute('href'))
len(wurl)

# %%
retex=[]
re=driver.find_elements(By.XPATH,'//div[contains(@class,"a-section a-spacing-none offers-items-content")]')
for r in re:
    if r.text is None :
        retex.append("--") 
    else:
        retex.append(d.text)

# %%
avail=[]
av=driver.find_elements(By.XPATH,'//div[contains(@class,"category")]')
for v in av:
    if v.text is None :
        avail.append("--") 
    else:
        avail.append(d.text)

# %%
df=pd.DataFrame({'WATCH':watch[:53],'PRICE':price[:53],'DELIVERY':delivery[:53],'URL':wurl[:53]})

# %%
df
# Out:
#                                                 WATCH      PRICE  \
# 0   GOQii Smart Vital Fitness SpO2, body temperatu...    [2,999]
# 1   GOQii Smart Vital Lite 1.4" Inch HD Full Touch...    [2,999]
# 2   boAt Xtend Smartwatch with Alexa Built-in, 1.6...    [3,498]
# 3   Noise ColorFit Pulse Spo2 Smart Watch with 10 ...    [2,499]
# 4   boAt Xtend Smartwatch with Alexa Built-in, 1.6...    [3,499]
# 5   GOQii Smart Vital Lite 1.4" Inch HD Full Touch...    [2,499]
# 6   Noise ColorFit Pro 2 Full Touch Control Smart ...    [3,199]
# 7   boAt Flash Edition Smartwatch with Activity Tr...    [1,899]
# 8   TAGG Verve NEO Smartwatch || 1.69'' Large Disp...    [3,999]
# 9   Noise ColorFit Pro 2 Full Touch Control Smart ...    [1,899]
# 10  boAt Xtend Smartwatch with Alexa Built-in, 1.6...    [1,999]
# 11  Noise ColorFit Pulse Smartwatch with 1.4" Full...    [1,999]
# 12  Helix by TIMEX SMART 2.0 Large 1.55" display F...    [2,499]
# ...

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # Q(3)

# %%
driver=webdriver.Chrome(r'/Users/nimeshroy/Downloads/chromedriver')
driver.get('https://images.google.com')
search=driver.find_element_by_xpath('/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input')
search.send_keys('cakes')
search.send_keys(Keys.ENTER)

# %%
for i in range(1,11):
    try:
        driver.find_element_by_xpath('//*[@id="islrg"]/div[1]/div['+str(i)+']/a[1]/div[1]/img').screenshot('/Users/nimeshroy/images/cake('+str(i)+').png')
    except:
        pass

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # Q(4)

# %%
driver=webdriver.Chrome(r'/Users/nimeshroy/Downloads/chromedriver')
driver.get('https://www.flipkart.com')
search=driver.find_element_by_xpath('//*[@id="container"]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input')
search.send_keys('motorola')
search.send_keys(Keys.ENTER)

# %%
containers=driver.find_elements(By.XPATH,'//div[contains(@class,"_2kHMtA")]')
print(type(containers), len(containers))

# %%
product_name=[]
for container in containers:
    product=container.find_elements_by_class_name('_4rR01T')
    print(product[0].text.strip())
    product_name.append(product[0].text)
len(product_name)

# %%
ram_rom=[]
for a in containers:
    ram=a.find_elements_by_class_name('rgWa7D')
    print(ram[0].text.strip())
    ram_rom.append(ram[0].text)
len(ram_rom)

# %%
display_size=[]
for b in containers:
    dispaly=b.find_elements_by_class_name('rgWa7D')
    print(dispaly[1].text.strip())
    display_size.append(dispaly[1].text)
len(display_size)

# %%
camera_features=[]
for c in containers:
    camera=c.find_elements_by_class_name('rgWa7D')
    print(camera[2].text)
    camera_features.append(camera[2].text)
len(camera_features)

# %%
battery_capacity=[]
for d in containers:
    battery=d.find_elements_by_class_name('rgWa7D')
    print(battery[3].text.strip())
    battery_capacity.append(battery[3].text)
len(battery_capacity)

# %%
price=[]
rate=driver.find_elements(By.XPATH,'//div[contains(@class,"_30jeq3 _1_WHN1")]')
for p in rate:    
    print(p.text)
    price.append(p.text)
len(price)

# %%
url=[]
link=driver.find_elements(By.XPATH,'//a[contains(@class,"_1fQZEK")]')
for l in link:
    print(l.get_attribute('href'))
    url.append(l.get_attribute('href'))
len(url)

# %%
df=pd.DataFrame()
df['MODEL']=product_name
df['RAM & ROM']=ram_rom
df['DISPLAY']=display_size
df['CAMERA']=camera_features
df['BATTERY']=battery_capacity
df['PRICE']=price
df['PRODUCT URL']=url

# %%
df
# Out:
#                                                 MODEL  \
# 0                     MOTOROLA G60 (Moonless, 128 GB)
# 1                  MOTOROLA G60 (Soft Silver, 128 GB)
# 2                     MOTOROLA g31 (Baby Blue, 64 GB)
# 3          MOTOROLA AP 450 Portable Room Air Purifier
# 4                   MOTOROLA e40 (Carbon Gray, 64 GB)
# 5          MOTOROLA G40 Fusion (Dynamic Gray, 128 GB)
# 6                MOTOROLA g31 (Meteorite Grey, 64 GB)
# 7                     MOTOROLA e40 (Pink Clay, 64 GB)
# 8              MOTOROLA E7 Power (Tahiti Blue, 64 GB)
# 9     MOTOROLA G40 Fusion (Frosted Champagne, 128 GB)
# 10              MOTOROLA g31 (Meteorite Grey, 128 GB)
# 11                  Moto G71 5G (Arctic Blue, 128 GB)
# 12                                       Motorola a10
# 13  MOTOROLA 10.5 kg Smart Wi-Fi Enabled Inverter ...
# 14                                       Motorola a10
# 15               MOTOROLA G51 5G (Indigo Blue, 64 GB)
# ...

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # Q(5)

# %%
driver=webdriver.Chrome(r'/Users/nimeshroy/Downloads/chromedriver')
driver.get('https://maps.google.com')
search=driver.find_element_by_xpath('//*[@id="searchboxinput"]')
search.send_keys('Gwalior')
search.send_keys(Keys.ENTER)

# %%
import googlemaps

# %%
gmaps_key=googlemaps.Client(key='AIzaSyD6-kcw70uO9cQcbwyrLP_Ho_sEn2wSqLY')

# %%
df['LATITUDE']=None
df['LONGITUDE']=None
for i in range(0,len(df),1):
    geocode=gmaps_key.geocode(df.iat[i,0])
    try:
        lat=geocode[0]['geometry']['locaton']['lat']
        lng=geocode[0]['geometry']['locaton']['lng']
        df.iat[i,df.columns.get_loc('LATITUDE')]=lat
        df.iat[i,df.columns.get_loc('LONGITUDE')]=lng
    except:
        lat=None
        lon=None
df

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # Q(6)

# %%
driver=webdriver.Chrome(r'/Users/nimeshroy/Downloads/chromedriver')
driver.get('https://www.trak.in')
driver.find_element_by_xpath('//*[@id="menu-item-51510"]').click()

# %%
date=[]
dat=driver.find_elements_by_class_name("column-2")
for d in dat:
    print(d.text)
    date.append(d.text)
len(date)

# %%
name=[]
na=driver.find_elements_by_class_name("column-3")
for n in na:
    print(n.text)
    name.append(n.text)
len(name)

# %%
industry=[]
it=driver.find_elements_by_class_name("column-4")
for s in it:
    print(s.text)
    industry.append(s.text)
len(industry)

# %%
subv=[]
su=driver.find_elements_by_class_name("column-5")
for u in su:
    print(u.text)
    subv.append(u.text)
len(subv)

# %%
city=[]
ci=driver.find_elements_by_class_name("column-6")
for c in ci:
    print(c.text)
    city.append(c.text)
len(city)

# %%
iname=[]
ina=driver.find_elements_by_class_name("column-7")
for e in ina:
    print(e.text)
    iname.append(e.text)
len(iname)

# %%
itype=[]
ity=driver.find_elements_by_class_name("column-8")
for y in ity:
    print(y.text)
    itype.append(y.text)
len(itype)

# %%
amount=[]
am=driver.find_elements_by_class_name("column-9")
for a in am:
    print(a.text)
    amount.append(a.text)
len(amount)

# %%
df=pd.DataFrame({'DATE':date,'STARTUP NAME':name,'INDUSTRY VERTICAL':industry,'SUBVERTICAL':subv,'CITY':city,'INVESTOR':iname,'INVESTMENT TYPE':itype,'AMOUNT(In USD)':amount})
df
# Out:
#                   DATE    STARTUP NAME     INDUSTRY VERTICAL  \
# 0    Date (dd/mm/yyyy)    Startup Name   Industry / Vertical
# 1
# 2           01/04/2021          BYJU’S              Edu-tech
# 3           05/04/2021          Meesho            E-commerce
# 4           14/04/2021          Swiggy  Online Food Delivery
# ..                 ...             ...                   ...
# 477         09/07/2018        zippserv     Consumer Internet
# 478         09/07/2018           Groww     Consumer Internet
# 479         10/07/2018   Avenue Growth     Consumer Internet
# 480         10/07/2018           iNICU            Healthcare
# 481         10/07/2018  Kinara Capital               Finance
#
#                                            SUBVERTICAL             CITY  \
# 0                                         Sub-Vertical  City / Location
# 1
# 2                                      Online tutoring        Bengaluru
# ...

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # Q(7)

# %%
driver=webdriver.Chrome(r'/Users/nimeshroy/Downloads/chromedriver')
driver.get('https://www.digit.in')
search=driver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div[2]/div[4]/ul/li[9]/a')
search.click()
#driver.find_element_by_xpath('/html/body/div[5]/div[1]/div[4]/div[2]/div[2]/div[2]/span[1]').click()
contain=driver.find_elements(By.XPATH,'//div[contains(@class,"Specs-Wrap")]')

# %%
os=[]
for o in contain:
    w=o.find_elements_by_class_name("value")
    print(w[0].text)
    os.append(w[0].text)
len(os)

# %%
display=[]
for e in contain:
    x=e.find_elements_by_class_name("value")
    print(x[1].text)
    display.append(x[1].text)
len(display)

# %%
processor=[]
for p in contain:
    s=p.find_elements_by_class_name("value")
    print(s[2].text)
    processor.append(s[2].text)
len(processor)

# %%
memory=[]
for m in contain:
    r=m.find_elements_by_class_name("value")
    print(r[3].text)
    memory.append(r[3].text)
len(memory)

# %%
name=[]
title=driver.find_elements(By.XPATH,'//div[contains(@class,"TopNumbeHeading sticky-footer")]')
for t in title:
    print(t.text)
    name.append(t.text)
len(name)

# %%
df=pd.DataFrame()
df['MODEL']=name
df['OPERATING SYSTEM']=os
df['DISPLAY']=display
df['PROCESSOR']=processor
df['MEMORY']=memory

# %%
df
# Out:
#                               MODEL OPERATING SYSTEM              DISPLAY  \
# 0                  1.\nHP VICTUS 16       WINDOWS 10  16.1" (1920 X 1200)
# 1                    2.\nHP OMEN 15  WINDOWS 10 HOME  15.6" (1920 X 1080)
# 2                  3.\nACER NITRO 5       WINDOWS 10  15.6" (1920 X 1080)
# 3               4.\nMSI STEALTH 15M       WINDOWS 10  15.6" (1920 X 1080)
# 4        5.\nASUS ROG STRIX SCAR 15       WINDOWS 10  15.6" (2560 X 1440)
# 5        6.\nASUS ROG STRIX SCAR 15  WINDOWS 10 HOME  15.6" (1920 X 1080)
# 6             7.\nASUS ZEPHYRUS G14  WINDOWS 10 HOME    14" (1920 X 1080)
# 7              8.\nLENOVO LEGION 5I   WINDOWS 10 PRO  15.6" (1920 X 1080)
# 8      9.\nASUS ROG ZEPHYRUS DUO 15       WINDOWS 10  15.6" (3840 X 1100)
# 9  10.\nACER ASPIRE 7 GAMING LAPTOP  WINDOWS 10 HOME  15.6" (1920 X 1080)
#
#                                     PROCESSOR                   MEMORY
# 0          5TH GEN AMD RYZEN 7 5800H | 3.2GHZ  512 GB SSD/16 GBGB DDR4
# ...

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # Q(8)

# %%
driver=webdriver.Chrome(r'/Users/nimeshroy/Downloads/chromedriver')
driver.get('https://www.forbes.com')
search=driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[1]/button[1]')
search.click()
driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]').click()
driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a').click()

# %%
rank=[]
name=[]
networth=[]
age=[]
country=[]
source=[]
industry=[]

# %%
ra=driver.find_elements(By.XPATH,'//div[contains(@class,"rank")]')
for r in ra:
    print(r.text)
    rank.append(r.text)
len(rank)

# %%
na=driver.find_elements(By.XPATH,'//div[contains(@class,"personName")]')
for n in na:
    print(n.text)
    name.append(n.text)
len(name)

# %%
ne=driver.find_elements(By.XPATH,'//div[contains(@class,"netWorth")]')
for t in ne:
    print(t.text)
    networth.append(t.text)
len(networth)

# %%
ag=driver.find_elements(By.XPATH,'//div[contains(@class,"age")]')
for g in ag:
    if g.text is None :
        age.append("--") 
    else:
        age.append(g.text)

# %%
co=driver.find_elements(By.XPATH,'//div[contains(@class,"countryOfCitizenship")]')
for u in co:
    print(u.text)
    country.append(u.text)

# %%
so=driver.find_elements(By.XPATH,'//div[contains(@class,"source-column")]')
for s in so:
    print(s.text)
    source.append(s.text)

# %%
ind=driver.find_elements(By.XPATH,'//div[contains(@class,"category")]')
for d in ind:
    if d.text is None :
        industry.append("--") 
    else:
        industry.append(d.text)

# %%
df=pd.DataFrame()
df["Rank"]=rank[0:200]
df["Name"]=name[0:200]
df["Networth"]=networth[0:200]
df["Age"]=age[0:200]
df["Country"]=country[0:200]
df["Source"]=source[0:200]
df["Industry"]=industry[0:200]
df
# Out:
#      Rank                      Name   Networth  \
# 0      2.                      NAME  NET WORTH
# 1      1.                Jeff Bezos     $177 B
# 2    RANK                 Elon Musk     $151 B
# 3      1.  Bernard Arnault & family     $150 B
# 4      2.                Bill Gates     $124 B
# ..    ...                       ...        ...
# 195  193.          Viktor Rashnikov    $11.2 B
# 196  194.           Harry Triguboff    $11.2 B
# 197  195.              Leonid Fedun    $11.1 B
# 198  195.                 Eyal Ofer    $11.1 B
# 199  197.              Evan Spiegel    $11.1 B
#
#                                                    Age              Country  \
# 0    Forbes World's Billionaires List\nThe Richest ...  COUNTRY / TERRITORY
# 1                                                  AGE        United States
# 2                                                   99        United States
# 3                                                   97               France
# ...

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # Q(9)

# %%
def Scrapcomments(url):
    driver=webdriver.Chrome(r'/Users/nimeshroy/Downloads/chromedriver')
    driver.get('https://www.youtube.com/watch?v=QSNa8U1yGrM')
    sleep(10)

    prev_h=0
    while True:
        height=driver.execute_script("""
              function getActualHeight(){
                  return Math.max(
                      Math.max(document.body.scrollHeight, document.documentElement.scrollHeight),
                      Math.max(document.body.offsetHeight, document.documentElement.offsetHeight),
                      Math.max(document.body.clientHeight, document.documentElement.clientHeight),
                   );
               }
               return getActualHeight();
            """)
        driver.execute_script(f"window.scrollTo({prev_h},{prev_h + 300})")
        time.sleep(2)
        prev_h += 300
        if prev_h >= height:
            break
    comment=[]
    com=driver.find_elements_by_class_name("style-scope ytd-comment-renderer")
    for i in com:
        print(i.text)
        print('XXXX---------------------------->>>>')
        comment.append(i.text)
    len(comment)

    
Scrapcomments(url)

# %% [markdown]
# # -------------------------------------

# %% [markdown]
# # Q(10)

# %%
driver=webdriver.Chrome(r'/Users/nimeshroy/Downloads/chromedriver')
driver.get('https://www.hostelworld.com/in')
driver.find_element_by_id('home-search-keywords').send_keys('London, England')
sleep(3)
driver.find_element_by_xpath('/html/body/div[1]/div[1]/div[2]/section/div/form/div/div[2]').click()

# %%
title=[]
ti=driver.find_elements(By.XPATH,'//h2[contains(@class,"title title-6")]')
for t in ti:
    title.append(t.text)

# %%
ti_1=driver.find_elements(By.XPATH,'//h2[contains(@class,"title title-6")]')
for a in ti_1:
    title.append(a.text)

# %%
distance=[]
di=driver.find_elements_by_class_name('description')
for d in di:
    distance.append(d.text)
distance

# %%
di_1=driver.find_elements(By.XPATH,'//span[contains(@class,"description")]')
for b in di_1:
    distance.append(b.text)

# %%
ratings=[]
ra=driver.find_elements(By.XPATH,'//div[contains(@class,"rating rating-summary-container big")]')
for r in ra:
    ratings.append(r.text.replace('\n',','))
ratings

# %%
ra_1=driver.find_elements(By.XPATH,'//div[contains(@class,"rating rating-summary-container big")]')
for n in ra_1:
    ratings.append(n.text.replace('\n',','))

# %%
facilities=[]
fac=driver.find_elements(By.XPATH,'//div[contains(@class,"facilities-label facilities")]')
for f in fac:
    print(f.text)
    facilities.append(f.text)

# %%
fac_1=driver.find_elements(By.XPATH,'//div[contains(@class,"facilities-label facilities")]')
for g in fac_1:
    print(g.text)
    facilities.append(g.text)

# %%
pdescription=[]
pr=driver.find_elements(By.XPATH,'//div[contains(@class,"rating-factors prop-card-tablet rating-factors small")]')
for r in pr:
    print(r.text)
    pdescription.append(r.text)

# %%
pr_1=driver.find_elements(By.XPATH,'//div[contains(@class,"rating-factors prop-card-tablet rating-factors small")]')
for c in pr_1:
    print(c.text)
    pdescription.append(c.text)

# %%
df=pd.DataFrame({'TITLE':title,'DISTANCE':distance,'RATINGS':ratings,'FACILITIES':facilities,'PROPERTY DESCRIPTION':pdescription})
df
# Out:
#                                       TITLE  \
# 0                          Astor Museum Inn
# 1         Safestay London Elephant & Castle
# 2                          Generator London
# 3                      Urbany Hostel London
# 4                           Astor Hyde Park
# 5                             Pickwick Hall
# 6                   Smart Camden Inn Hostel
# 7              No.8 Willesden Hostel London
# 8                        No.8 Seven Sisters
# 9                        London Backpackers
# 10              Smart Russell Square Hostel
# 11                 YHA London Oxford Street
# 12                 Barmy Badger Backpackers
# 13  Safestay London Kensington Holland Park
# 14                  Prime Backpackers Angel
# 15              Smart Hyde Park View Hostel
# 16     St Christopher's Inn - London Bridge
# 17                  Queen Elizabeth Chelsea
# 18              Wombat's City Hostel London
# 19                           Phoenix Hostel
# ...

# %% [markdown]
# # -----------XXXXXXXX-------------
